# %% [markdown]
# # Módulo juzgados
# Significado auditado de las columnas `col_NN` de los cuadros 4.1.x y jerarquía de filas del 4.1.1.
# Transcripción literal de `propuesta_encabezados_juzgados.csv` y `propuesta_filas_4_1_1.csv`.
# Una misma `col_NN` significa cosas distintas en cada cuadro: la clave es siempre (cuadro, columna).

# %%
ENCABEZADOS_TABLA = [
    # cuadro, columna, rotulo_canonico, codigo_canonico, tipo_columna, decision, confianza
    ('4.1.1', 'col_01', 'Sucre', 'ciudad_sucre', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_02', 'La Paz', 'ciudad_la_paz', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_03', 'El Alto', 'ciudad_el_alto', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_04', 'Cochabamba', 'ciudad_cochabamba', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_05', 'Oruro', 'ciudad_oruro', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_06', 'Potosí', 'ciudad_potosi', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_07', 'Tarija', 'ciudad_tarija', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_08', 'Santa Cruz', 'ciudad_santa_cruz', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_09', 'Trinidad', 'ciudad_trinidad', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_10', 'Cobija', 'ciudad_cobija', 'otro', 'confirmado', 'alta'),
    ('4.1.1', 'col_11', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.2', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.2', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_03', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_04', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_05', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_06', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_07', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_08', 'Juzgado Sentencia, Público y Trabajo', 'juzgado_sentencia_publico_trabajo', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_09', 'Tribunal de Sentencia (Nominal)', 'tribunal_sentencia_nominal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_10', 'Ejecución Penal', 'ejecucion_penal', 'organo_judicial', 'confirmado_variacion_editorial', 'alta'),
    ('4.1.2', 'col_11', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.2', 'col_12', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.2', 'col_13', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.3', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.3', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_03', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_04', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_05', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_06', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_07', 'Juzgado Sentencia, Público, Trabajo y Juez Técnico', 'juzgado_sentencia_publico_trabajo_juez_tecnico', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_08', 'Tribunal de Sentencia', 'tribunal_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_09', 'Tribunal de Sentencia con Ampliación de Competencias', 'tribunal_sentencia_ampliacion_competencias', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_10', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.3', 'col_11', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.3', 'col_12', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.4', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.4', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_03', 'Juzgado Público de la Niñez y Adolescencia', 'juzgado_publico_ninez_adolescencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_04', 'Juzgado Público de Familia', 'juzgado_publico_familia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_05', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_06', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_07', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_08', 'Juzgado Público Mixto y de Sentencia Penal', 'juzgado_publico_mixto_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_09', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_10', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_11', 'Juzgado Partido Mixto Sentencia', 'juzgado_partido_mixto_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_12', 'Juzgado de Partido del Trabajo y Seguridad Social', 'juzgado_partido_trabajo_seguridad_social', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_13', 'Juzgado de Sentencia', 'juzgado_sentencia', 'organo_judicial', 'confirmado_variacion_editorial', 'alta'),
    ('4.1.4', 'col_14', 'Juzgado Sentencia, Público, Trabajo y Juez Técnico', 'juzgado_sentencia_publico_trabajo_juez_tecnico', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_15', 'Tribunal de Sentencia con Ampliación de Competencias', 'tribunal_sentencia_ampliacion_competencias', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_16', 'Tribunal de Sentencia', 'tribunal_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_17', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.4', 'col_18', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.4', 'col_19', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.5', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.5', 'col_02', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_03', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_04', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_05', 'Juzgado Sentencia, Público y Trabajo', 'juzgado_sentencia_publico_trabajo', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_06', 'Tribunal de Sentencia (Nominal)', 'tribunal_sentencia_nominal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_07', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.5', 'col_08', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.5', 'col_09', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.6', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.6', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_03', 'Juzgado Público de Familia', 'juzgado_publico_familia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_04', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_05', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_06', 'Juzgado Público Mixto y de Sentencia Penal', 'juzgado_publico_mixto_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_07', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_08', 'Juzgado Sentencia, Público, Trabajo y Juez Técnico', 'juzgado_sentencia_publico_trabajo_juez_tecnico', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_09', 'Tribunal de Sentencia (Nominal)', 'tribunal_sentencia_nominal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_10', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.6', 'col_11', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.6', 'col_12', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.7', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.7', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_03', 'Juzgado Público de Familia', 'juzgado_publico_familia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_04', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_05', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_06', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_07', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_08', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_09', None, None, 'indeterminado', 'indeterminado', 'baja'),
    ('4.1.7', 'col_10', 'Juzgado Sentencia, Público, Trabajo y Juez Técnico', 'juzgado_sentencia_publico_trabajo_juez_tecnico', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_11', 'Tribunal de Sentencia con Ampliación de Competencias', 'tribunal_sentencia_ampliacion_competencias', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_12', 'Tribunal de Sentencia', 'tribunal_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_13', 'Ejecución Penal', 'ejecucion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_14', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.7', 'col_15', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.7', 'col_16', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.8', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.8', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_03', 'Juzgado Público de Familia', 'juzgado_publico_familia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_04', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_05', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_06', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_07', 'Juzgado Público Mixto y de Sentencia Penal', 'juzgado_publico_mixto_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_08', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_09', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_10', 'Juzgado Partido Mixto', 'juzgado_partido_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_11', 'Juzgado de Sentencia', 'juzgado_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_12', 'Juzgado de Partido del Trabajo y SS e Instrucción Penal', 'juzgado_partido_trabajo_ss_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_13', 'Tribunal de Sentencia con Ampliación de Competencias', 'tribunal_sentencia_ampliacion_competencias', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_14', 'Tribunal de Sentencia', 'tribunal_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_15', 'Ejecución Penal', 'ejecucion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_16', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.8', 'col_17', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.8', 'col_18', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.9', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.9', 'col_02', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_03', 'Juzgado de Instrucción Contra la Violencia', 'juzgado_instruccion_contra_violencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_04', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_05', 'Juzgado Público Mixto', 'juzgado_publico_mixto', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_06', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_07', 'Juzgado Público Mixto, Partido e Instrucción Penal', 'juzgado_publico_mixto_partido_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_08', 'Juzgado Público Mixto, Partido y de Sentencia Penal', 'juzgado_publico_mixto_partido_sentencia_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_09', 'Juzgado de Sentencia', 'juzgado_sentencia', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_10', 'Juzgado Sentencia, Público, Trabajo y Juez Técnico', 'juzgado_sentencia_publico_trabajo_juez_tecnico', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_11', 'Tribunal de Sentencia con Ampliación de Competencias', 'tribunal_sentencia_ampliacion_competencias', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_12', 'Tribunal de Sentencia (Nominal)', 'tribunal_sentencia_nominal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_13', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.9', 'col_14', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.9', 'col_15', 'Total', 'total', 'total', 'confirmado', 'alta'),
    ('4.1.10', 'col_01', 'Población proyectada al 2022', 'poblacion_proyectada_2022', 'poblacion', 'confirmado', 'alta'),
    ('4.1.10', 'col_02', 'Juzgado Público Mixto e Instrucción Penal', 'juzgado_publico_mixto_instruccion_penal', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.10', 'col_03', 'Conciliador', 'conciliador', 'conciliador', 'confirmado', 'alta'),
    ('4.1.10', 'col_04', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'organo_judicial', 'confirmado', 'alta'),
    ('4.1.10', 'col_05', 'Total', 'total', 'total', 'confirmado', 'alta'),
]

FILAS_4_1_1_TABLA = [
    # fila_en_cuadro, fila_id, literal_original, rotulo_canonico, codigo_canonico, tipo_entidad, estructura, fila_padre_id, nivel_jerarquia, decision, confianza
    (1, 'f001', 'JUZGADOS DE INSTRUCCIÓN', 'Juzgados de Instrucción', 'juzgados_instruccion', 'juzgado', 'subtotal', 'f037', 1, 'confirmado', 'alta'),
    (2, 'f002', 'Penal', 'Juzgado de Instrucción Penal', 'juzgado_instruccion_penal', 'juzgado', 'detalle', 'f001', 2, 'confirmado', 'alta'),
    (3, 'f003', 'Anticorrupción y Contra la Violencia hacia las mujeres', 'Juzgado de Instrucción Anticorrupción y Contra la Violencia hacia las Mujeres', 'juzgado_instruccion_anticorrupcion_violencia_mujeres', 'juzgado', 'detalle', 'f001', 2, 'confirmado', 'alta'),
    (4, 'f004', 'Contra la Violencia hacia las mujeres', 'Juzgado de Instrucción Contra la Violencia hacia las Mujeres', 'juzgado_instruccion_violencia_mujeres', 'juzgado', 'detalle', 'f001', 2, 'confirmado', 'alta'),
    (5, 'f005', 'Anticorrupción', 'Juzgado de Instrucción Anticorrupción', 'juzgado_instruccion_anticorrupcion', 'juzgado', 'detalle', 'f001', 2, 'confirmado', 'alta'),
    (6, 'f006', 'JUZGADOS DE PARTIDO Y TRIBUNALES', 'Juzgados de Partido y Tribunales', 'juzgados_partido_tribunales', 'otro', 'subtotal', 'f037', 1, 'confirmado', 'alta'),
    (7, 'f007', 'Trabajo y Seguridad Social', 'Juzgado de Partido del Trabajo y Seguridad Social', 'juzgado_partido_trabajo_seguridad_social', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (8, 'f008', 'Adm. Coactivo Fiscal Tributario', 'Juzgado de Partido Adm. Coactivo Fiscal Tributario', 'juzgado_partido_adm_coactivo_fiscal_tributario', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (9, 'f009', 'Trabajo y Seguridad Social y Adm. Coactivo Fiscal y Tributario', 'Juzgado de Partido del Trabajo y Seguridad Social y Adm. Coactivo Fiscal y Tributario', 'juzgado_partido_trabajo_seguridad_social_adm_coactivo_fiscal_tributario', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (10, 'f010', 'Sentencia Penal', 'Juzgado de Sentencia Penal', 'juzgado_sentencia_penal', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (11, 'f011', 'Sentencia Contra la Violencia hacia las Mujeres', 'Juzgado de Sentencia Contra la Violencia hacia las Mujeres', 'juzgado_sentencia_violencia_mujeres', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (12, 'f012', 'Sentencia Anticorrupcion y Contra la Violencia hacia las mujeres', 'Juzgado de Sentencia Anticorrupción y Contra la Violencia hacia las Mujeres', 'juzgado_sentencia_anticorrupcion_violencia_mujeres', 'juzgado', 'detalle', 'f006', 2, 'confirmado_variacion_editorial', 'alta'),
    (13, 'f013', 'Sentencia Penal y Anticorrupción', 'Juzgado de Sentencia Penal y Anticorrupción', 'juzgado_sentencia_penal_anticorrupcion', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (14, 'f014', 'Sentencia Penal y Perdida de Dominio', 'Juzgado de Sentencia Penal y Pérdida de Dominio', 'juzgado_sentencia_penal_perdida_dominio', 'juzgado', 'detalle', 'f006', 2, 'confirmado_variacion_editorial', 'alta'),
    (15, 'f015', 'Sentencia Penal y Contra la Violencia hacia las mujeres', 'Juzgado de Sentencia Penal y Contra la Violencia hacia las Mujeres', 'juzgado_sentencia_penal_violencia_mujeres', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (16, 'f016', 'Tribunal de Sentencia', 'Tribunal de Sentencia', 'tribunal_sentencia', 'tribunal', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (17, 'f017', 'Tribunal de Sentencia Anticorrupcion y Contra la Violencia hacia las mujeres', 'Tribunal de Sentencia Anticorrupción y Contra la Violencia hacia las Mujeres', 'tribunal_sentencia_anticorrupcion_violencia_mujeres', 'tribunal', 'detalle', 'f006', 2, 'confirmado_variacion_editorial', 'alta'),
    (18, 'f018', 'Tribunal de Sentencia Anticorrupcion', 'Tribunal de Sentencia Anticorrupción', 'tribunal_sentencia_anticorrupcion', 'tribunal', 'detalle', 'f006', 2, 'confirmado_variacion_editorial', 'alta'),
    (19, 'f019', 'Ejecución Penal', 'Juzgado de Ejecución Penal', 'juzgado_ejecucion_penal', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (20, 'f020', 'Agroambientales', 'Juzgado Agroambiental', 'juzgado_agroambiental', 'juzgado', 'detalle', 'f006', 2, 'confirmado', 'alta'),
    (21, 'f021', 'JUZGADOS PUBLICOS', 'Juzgados Públicos', 'juzgados_publicos', 'juzgado', 'subtotal', 'f037', 1, 'confirmado_variacion_editorial', 'alta'),
    (22, 'f022', 'Civil y Comercial', 'Juzgado Público Civil y Comercial', 'juzgado_publico_civil_comercial', 'juzgado', 'detalle', 'f021', 2, 'confirmado', 'alta'),
    (23, 'f023', 'Familia', 'Juzgado Público de Familia', 'juzgado_publico_familia', 'juzgado', 'detalle', 'f021', 2, 'confirmado', 'alta'),
    (24, 'f024', 'Niñez y Adolescencia', 'Juzgado Público de la Niñez y Adolescencia', 'juzgado_publico_ninez_adolescencia', 'juzgado', 'detalle', 'f021', 2, 'confirmado', 'alta'),
    (25, 'f025', 'JUZGADOS MIXTOS', 'Juzgados Mixtos', 'juzgados_mixtos', 'juzgado', 'subtotal', 'f037', 1, 'confirmado', 'alta'),
    (26, 'f026', 'Instrucción Penal y Contra la Violencia hacia las Mujeres (EPI NORTE- EPI SUR)', 'Juzgado Mixto de Instrucción Penal y Contra la Violencia hacia las Mujeres (EPI Norte-EPI Sur)', 'juzgado_mixto_instruccion_penal_violencia_mujeres_epi_norte_sur', 'juzgado', 'detalle', 'f025', 2, 'confirmado', 'alta'),
    (27, 'f027', 'Público Civil y Comercial, de Familia e Instrucción Penal (EPI SUR Y SUD ESTE, Plan 3000)', 'Juzgado Mixto Público Civil y Comercial, de Familia e Instrucción Penal (EPI Sur y Sud Este, Plan 3000)', 'juzgado_mixto_publico_civil_comercial_familia_instruccion_penal_epi_sur_sud_este_plan_3000', 'juzgado', 'detalle', 'f025', 2, 'confirmado', 'alta'),
    (28, 'f028', 'Público Civil y Comercial, de Familia, Niñez y Adolscencia e Instrucción Penal (C. Integrado) y EPI Norte', 'Juzgado Mixto Público Civil y Comercial, de Familia, Niñez y Adolescencia e Instrucción Penal (C. Integrado) y EPI Norte', 'juzgado_mixto_publico_civil_comercial_familia_ninez_adolescencia_instruccion_penal_c_integrado_epi_norte', 'juzgado', 'detalle', 'f025', 2, 'confirmado_variacion_editorial', 'alta'),
    (29, 'f029', 'SALAS', 'Salas', 'salas', 'sala', 'subtotal', 'f037', 1, 'confirmado', 'alta'),
    (30, 'f030', 'Civil', 'Sala Civil', 'sala_civil', 'sala', 'detalle', 'f029', 2, 'confirmado', 'alta'),
    (31, 'f031', 'Penal', 'Sala Penal', 'sala_penal', 'sala', 'detalle', 'f029', 2, 'confirmado', 'alta'),
    (32, 'f032', 'Social Administrativa', 'Sala Social Administrativa', 'sala_social_administrativa', 'sala', 'detalle', 'f029', 2, 'confirmado', 'alta'),
    (33, 'f033', 'Familia, Niñez y Adolescencia', 'Sala de Familia, Niñez y Adolescencia', 'sala_familia_ninez_adolescencia', 'sala', 'detalle', 'f029', 2, 'confirmado', 'alta'),
    (34, 'f034', 'Constitucionales', 'Sala Constitucional', 'sala_constitucional', 'sala', 'detalle', 'f029', 2, 'confirmado', 'alta'),
    (35, 'f035', 'JUZGADOS DISCIPLINARIOS', 'Juzgados Disciplinarios', 'juzgados_disciplinarios', 'juzgado', 'detalle', 'f037', 1, 'confirmado', 'alta'),
    (36, 'f036', 'CONCILIADORES', 'Conciliadores', 'conciliadores', 'conciliador', 'detalle', 'f037', 1, 'confirmado', 'alta'),
    (37, 'f037', 'TOTAL GENERAL', 'Total general', 'total_general', 'otro', 'total_general', None, 0, 'confirmado', 'alta'),
]

ENCABEZADOS_JUZGADOS = {}
for c, col, rotulo, codigo, tipo, decision, confianza in ENCABEZADOS_TABLA:
    ENCABEZADOS_JUZGADOS[(c, col)] = {
        "rotulo_canonico": rotulo,
        "codigo_canonico": codigo,
        "tipo_columna": tipo,
        "decision": decision,
        "confianza": confianza,
    }

FILAS_4_1_1 = {}
for fila in FILAS_4_1_1_TABLA:
    FILAS_4_1_1[fila[0]] = {
        "fila_id": fila[1],
        "literal_original": fila[2],
        "rotulo_canonico": fila[3],
        "codigo_canonico": fila[4],
        "tipo_entidad": fila[5],
        "estructura": fila[6],
        "fila_padre_id": fila[7],
        "nivel_jerarquia": fila[8],
        "decision": fila[9],
        "confianza": fila[10],
    }

# %%
# Dos rótulos que el PDF parte en dos líneas y el parser cortaba; verificados a ojo en la página 109.
CORRECCIONES_LITERALES_4_1_1 = {
    27: ("Público Civil y Comercial, de Familia e Instrucción Penal (EPI SUR Y SUD ESTE, Plan",
         "Público Civil y Comercial, de Familia e Instrucción Penal (EPI SUR Y SUD ESTE, Plan 3000)"),
    28: ("Público Civil y Comercial, de Familia, Niñez y Adolscencia e Instrucción Penal (C.",
         "Público Civil y Comercial, de Familia, Niñez y Adolscencia e Instrucción Penal (C. Integrado) y EPI Norte"),
}


def describir_columna_juzgado(cuadro_origen, columna):
    return ENCABEZADOS_JUZGADOS.get((cuadro_origen, columna))


def describir_fila_4_1_1(cuadro_origen, fila_en_cuadro):
    if cuadro_origen != "4.1.1":
        return None
    return FILAS_4_1_1.get(int(fila_en_cuadro))


def corregir_literal_extraido(cuadro_origen, fila_en_cuadro, literal):
    if cuadro_origen != "4.1.1" or fila_en_cuadro not in CORRECCIONES_LITERALES_4_1_1:
        return literal
    truncado = CORRECCIONES_LITERALES_4_1_1[fila_en_cuadro][0]
    completo = CORRECCIONES_LITERALES_4_1_1[fila_en_cuadro][1]
    if literal == completo:
        return literal
    if literal != truncado:
        raise ValueError("Literal inesperado en 4.1.1/fila " + str(fila_en_cuadro) + ": " + repr(literal))
    return completo
